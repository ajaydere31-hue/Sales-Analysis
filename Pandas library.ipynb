# %%
# chi-square test 
import pandas as pd

# %%
data = [[70,20,40,90],
        [30,50,60,80]]

# %%
df = pd.DataFrame(data,columns=["P1","P2","P3","P4"],index= ["Female","Male"])

# %%
df
# Out:
#         P1  P2  P3  P4
# Female  70  20  40  90
# Male    30  50  60  80

# %%
import scipy

# %%
from scipy.stats import chi2_contingency

# %%
    chisquare,dof,p,expected = chi2_contingency(df)

# %%
print("Chi-square test :",round(chisqaure,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print("Chi-square test:",round(chisqaure,2))
#
# NameError: name 'chisqaure' is not defined

# %%
import seaborn as sns

# %%
import pamdas as pd 
import matplotlib as plt

# %%
plt.figure(figure=(10,3))
sns.histplot(df['price'],bins=100,kde=True)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.figure(figure=(10,3))
#       2 sns.histplot(df['price'],bins=100,kde=True)
#       3 plt.show
#
# NameError: name 'plt' is not defined
